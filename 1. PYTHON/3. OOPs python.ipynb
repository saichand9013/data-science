# %% [markdown]
# # OBJECT ORIENTED PROGRAMMING

# %% [raw]
# OOP stands for Object-Oriented Programming.
# Python is an object-oriented language, allowing you to structure your code using classes and objects for better organization and reusability.
# Provides a clear structure to programs
# Makes code easier to maintain, reuse, and debug
# Helps keep your code DRY (Don't Repeat Yourself)
# Allows you to build reusable applications with less code
# python is both compiled and interprited language

# %% [raw]
# Classes and objects are the two core concepts in object-oriented programming.
# class which are blueprint and objects which are entity
# procedure oriented | functional | object oriented
# Class	Objects
# Fruit	Apple, Banana, Mango
# Car	    Volvo, Audi, Toyota
# inheritance
# abstraction
# encapsulation
# polymorphism

# %% [markdown]
# # classes

# %% [raw]
# a class is a blueprint or template forcreating objects provides variables or attributes and behaviour functions or method
# A Class is like an object constructor, or a "blueprint" for creating objects.
# attributes/variables
# methods/functions

# %%
class person:
    name='sai'
    occupation='student'

# %%
class person:
    name='sai'
    occupation='student'
    def info(self):
        print(f"{self.name} is a {self.occupation}")

a=person()
b=person()
a.name="saichand"
a.occupation='engineer'

a.info() 
b.info()
# Out:
# saichand is a engineer
# sai is a student

# %%
class students:
    def __init__(self,name,occupation):
        self.name=name
        self.occupation=occupation
    def info(self):
        print(f"{self.name} is {self.occupation}")
s1=students('kiran','it')
s2=students('ramesh','engineer')
s1.info()
s2.info()
# Out:
# kiran is it
# ramesh is engineer

# %% [markdown]
# # object

# %% [raw]
# it is instance or entity of the class used to access the properties of the class

# %%
#class
class details:     #creating a class
    name="sai"
    age=21
    def teacher(self):
        print("python")

s1=details()       #creating a object
print(s1.name)
print(s1.age)

#details.teacher()-works when no self pareamater given
details.teacher(s1)
details.name

s1.teacher()
# Out:
# sai
# 21
# python
# python

# %%
s2=details()
print(s2.name)

s3=details()         #multiple objects
s4=details()

print(type(s3))   #object user defined clss
x=9
print(type(x))     #int built in class

del s2         #deleting a object
# Out:
# sai
# <class '__main__.details'>
# <class 'int'>

# %%
#pass statement: class definitions cannot be empty, but if you for some reason have a class definition with no content,
#put in the pass statement to avoid getting an error.

class person:
    pass

obj1=person()

# %% [markdown]
# # init

# %%
class Person:
  pass

p1 = Person()                  # without init set properties manually
p1.name = "Tobias"
p1.age = 25

print(p1.name)
print(p1.age)
# Out:
# Tobias
# 25

# %%
class Person:
  def __init__(self, name, age):          #using init
    self.name = name
    self.age = age

p1 = Person("Emil", 36)

print(p1.name)
print(p1.age)
# Out:
# Emil
# 36

# %%
class Person:
  def __init__(self, name='student', age=18):          #default values in init
    self.name = name
    self.age = age

p1 = Person("Emil",20)
p2 = Person("Emil")

print(p1.name,p1.age)
print(p2.name,p2.age)
# Out:
# Emil 20
# Emil 18

# %%
class Person:
  def __init__(self, name, age, city, country):        #multiple parameters
    self.name = name
    self.age = age
    self.city = city
    self.country = country

p1 = Person("Linus", 30, "Oslo", "Norway")

print(p1.name)
print(p1.age)
print(p1.city)
print(p1.country)
# Out:
# Linus
# 30
# Oslo
# Norway

# %%
class Person:

  def __init__(self, name, occ):          #constructor method
    print("Hey I am a person")
    self.name = name
    self.occ = occ
                 
  def info(self):
    print(f"{self.name} is a {self.occ}")


a = Person("Harry", "Developer")
b = Person("Divya", "HR") 
a.info()
b.info()
# Out:
# Hey I am a person
# Hey I am a person
# Harry is a Developer
# Divya is a HR

# %%
class car:
    wheels=4            #class variable
    def __init__(self):
        self.mil=18           #instance variable(static variables)
        self.com='audi'
c1=car()
c2=car()
print(c1.com,c1.mil,c1.wheels)
print(c2.com,c2.mil,c2.wheels)
# Out:
# audi 18 4
# audi 18 4

# %% [markdown]
# #self parameter

# %% [markdown]
# # getters setters

# %%
class student:
    school='telusko'
    def __init__(self,m1,m2,m3):
        self.m1=m1
        self.m2=m2
        self.m3=m3
    def avg(self):                         #instance method
        return (self.m1+self.m2+self.m3)/3

    def get_m1(self):            #accessors methods/
        return self.m1
    def set_m1(self):           #mutators methods
        self.m1=value

    @classmethod
    def getschool(cls):                 #class method
        return cls.school
        
    @staticmethod                      #static method
    def info():
        print("this is student class.")

    @staticmethod                    #acts as a normal function
    def add(a,b):
        return a+b
        
        
s1=student(34,67,23)
s2=student(23,53,22)
print(s1.avg())
print(student.getschool())
student.info()
student.add(5,8)
# Out:
# 41.333333333333336
# telusko
# this is student class.
# 13

# %%
class MyClass:
  def __init__(self, value):
      self._value = value
    
  def show(self):
    print(f"Value is {self._value}")
    
  @property                           #getter
  def ten_value(self):
      return 10* self._value
    
  @ten_value.setter                   #setter
  def ten_value(self, new_value):
      self._value = new_value/10

obj = MyClass(10)
obj.ten_value = 67
print(obj.ten_value)
obj.show()
# Out:
# 67.0
# Value is 6.7

# %%
# inner class

class student:
    def __init__(self,name,rollno):
        self.name=name
        self.rollno=rollno

    def show(self):
        print(self.name,self.rollno)

    class laptop:                        #inner class
        def __init__(self):
            self.brand='dell'
            self.cpu='i5'
    

s1=student("kiran",25)
s2=student("jhansi",20)
s1.show()
#lap1=s1.lap
# Out:
# kiran 25

# %% [markdown]
# # dir , dict ,  help

# %%
x=[1,2,3]           
dir(x)           #prints all the methodsa and functions of list/tuple etc
# Out:
# ['__add__',
#  '__class__',
#  '__class_getitem__',
#  '__contains__',
#  '__delattr__',
#  '__delitem__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getitem__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__iadd__',
#  '__imul__',
#  '__init__',
#  '__init_subclass__',
#  '__iter__',
#  '__le__',
#  '__len__',
#  '__lt__',
#  '__mul__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__reversed__',
#  '__rmul__',
#  '__setattr__',
#  '__setitem__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  'append',
#  'clear',
#  'copy',
#  'count',
#  'extend',
#  'index',
#  'insert',
#  'pop',
#  'remove',
#  'reverse',
#  'sort']

# %%
class person:
    def __init__(self,name,age):
        self.name=name
        self.age=age
p=person("john",30)
print(p.__dict__)                #returns a dictonary representation of an objects attributes
# Out:
# {'name': 'john', 'age': 30}

# %%
help(str)
# Out:
# Help on class str in module builtins:
#
# class str(object)
#  |  str(object='') -> str
#  |  str(bytes_or_buffer[, encoding[, errors]]) -> str
#  |
#  |  Create a new string object from the given object. If encoding or
#  |  errors is specified, then the object must expose a data buffer
#  |  that will be decoded using the given encoding and error handler.
#  |  Otherwise, returns the result of object.__str__() (if defined)
#  |  or repr(object).
#  |  encoding defaults to 'utf-8'.
#  |  errors defaults to 'strict'.
#  |
#  |  Methods defined here:
#  |
#  |  __add__(self, value, /)
#  |      Return self+value.
#  |
#  |  __contains__(self, key, /)
#  |      Return bool(key in self).
#  |
#  |  __eq__(self, value, /)
#  |      Return self==value.
#  |
#  |  __format__(self, format_spec, /)
#  |      Return a formatted version of the string as described by format_spec.
#  |
#  |  __ge__(self, value, /)
#  |      Return self>=value.
#  |
#  |  __getitem__(self, key, /)
# ...

# %% [markdown]
# # magic/dunder methods

# %%
class Employee:

  def __init__(self, name):
    self.name = name

  def __len__(self):
    i = 0
    for c in self.name:
      i = i + 1
    return i

  def __str__(self):
    return f"The name of the employee is {self.name} str"
    
  def __repr__(self):
    return f"Employee('{self.name}')"

  def __call__(self):
    print("Hey I am good")

# %% [markdown]
# # inheritance

# %% [raw]
# Inheritance allows us to define a class that inherits all the methods and properties from another class.
# Parent class is the class being inherited from, also called base class.
# Child class is the class that inherits from another class, also called derived class.
# 1. single inheritance
# 2. multiple inheritance
# 3.multi level inheritance
# 4. hirerchial inheritance
# 5. hybrid inheritance
# # sub class can access all the featurs from super class but
# super class cannot access any feature  from the sub class
#
# #if you create the object of sub calss it will first try to find init of the sub class
# if it is not found then it will call init of the super class

# %%
class A:                   #parent class
    def option1(self):
        print("option one okay")
    def option2(self):
        print("option two is okay")
class B(A):                           #single inheritance
    def option3(self):                   #child class
        print("option 3 is okay")
    def option4(self):
        print("option 4 is okay")
a1=A()
a1.option1()

b1=B()
b1.option1()
# Out:
# option one okay
# option one okay

# %%
class A:                   #parent class
    def option1(self):
        print("option one okay")
    def option2(self):
        print("option two is okay")
class B(A):                           #single inheritance
    def option3(self):                   #child class
        print("option 3 is okay")
    def option4(self):
        print("option 4 is okay")
class C(B):                            #multi level inheritance
    def option5(self):
        print("option 5 is okay")
class D():
    def option6(self):
        print("option 6 is okay")
class E():
    def option7 (self):
        print("option 7 is okay")
class F(D,E):                             #multiple inheritance
    def option7(self):
        print("this is multiple inheritance")
        
a1=A()
a1.option1()

b1=B()
b1.option1()
# Out:
# option one okay
# option one okay

# %%
#single inheritance
class Animal:
    def __init__(self, name, species):
        self.name = name
        self.species = species
        
    def make_sound(self):
        print("Sound made by the animal")

class Dog(Animal):
    def __init__(self, name, breed):
        Animal.__init__(self, name, species="Dog")
        self.breed = breed
        
    def make_sound(self):
        print("Bark!")

d = Dog("Dog", "Doggerman")
d.make_sound()

a = Animal("Dog", "Dog")
a.make_sound()
# Out:
# Bark!
# Sound made by the animal

# %%
#multiple inheritance
class Employee:
  def __init__(self, name):
    self.name = name
  def show(self):
    print(f"The name is {self.name}")

class Dancer:
  def __init__(self, dance):
    self.dance = dance

  def show(self):
    print(f"The dance is {self.dance}")

class DancerEmployee(Employee, Dancer):
  def __init__(self, dance, name):
    self.dance = dance
    self.name = name

o  = DancerEmployee("Kathak", "Shivani")
print(o.name)
print(o.dance)
o.show() 
print(DancerEmployee.mro())              #order in which it prints the content
# Out:
# Shivani
# Kathak
# The name is Shivani
# [<class '__main__.DancerEmployee'>, <class '__main__.Employee'>, <class '__main__.Dancer'>, <class 'object'>]

# %%
#multilevel inheritance
class Animal:
    def __init__(self, name, species):
        self.name = name
        self.species = species
        
    def show_details(self):
        print(f"Name: {self.name}")
        print(f"Species: {self.species}")
        
class Dog(Animal):
    def __init__(self, name, breed):
        Animal.__init__(self, name, species="Dog")
        self.breed = breed
        
    def show_details(self):
        Animal.show_details(self)
        print(f"Breed: {self.breed}")
        
class GoldenRetriever(Dog):
    def __init__(self, name, color):
        Dog.__init__(self, name, breed="Golden Retriever")
        self.color = color
        
    def show_details(self):
        Dog.show_details(self)
        print(f"Color: {self.color}")

o = Dog("tommy", "Black")
o.show_details()
print(GoldenRetriever.mro())         #method resolution order
# Out:
# Name: tommy
# Species: Dog
# Breed: Black
# [<class '__main__.GoldenRetriever'>, <class '__main__.Dog'>, <class '__main__.Animal'>, <class 'object'>]

# %%
#hybrid inheritance 
class BaseClass:
  pass

class Derived1(BaseClass):
  pass  

class Derived2(BaseClass):
  pass  

class Derived3(Derived1, Derived2):
  pass

# %%
#hirerchial inheritance
class BaseClass:
  pass

class D1(BaseClass):
  pass

class D2(BaseClass):
  pass

class D3(D1):
  pass

# %% [markdown]
# # super keyword

# %% [raw]
# Python also has a super() function that will make the child class inherit all the methods and properties from its parent:
# when you wnat to call the init of both the class we use super class

# %%
class Person:
  def __init__(self, fname, lname):
    self.firstname = fname
    self.lastname = lname

  def printname(self):
    print(self.firstname, self.lastname)
class Student(Person):
  def __init__(self, fname, lname, year):
    super().__init__(fname, lname)
    self.graduationyear = year

x = Student("Mike", "Olsen", 2019)
x.printname()
# Out:
# Mike Olsen

# %%
class Employee:
  def __init__(self, name, id):
    self.name = name
    self.id = id

class Programmer(Employee):
  def __init__(self, name, id, lang):
    super().__init__( name, id)
    self.lang = lang

rohan = Employee("Rohan ", "420")
harry = Programmer("sai", "2345", "Python")
print(harry.name)
print(harry.id)
print(harry.lang)
# Out:
# sai
# 2345
# Python

# %% [markdown]
# # constructor in inheritance

# %% [raw]
# #The __init__() function is called automatically every time the class is being used to create a new object.
# #When you add the __init__() function, the child class will no longer inherit the parent's __init__() function.
# #The child's __init__() function overrides the inheritance of the parent's __init__() function.

# %%
class Person:
  def __init__(self, fname, lname):
    self.firstname = fname
    self.lastname = lname

  def printname(self):
    print(self.firstname, self.lastname)

# %%
class A: 
    def __init__(self):
        print("in  a init")
    def option1(self):
        print("option one okay")
    def option2(self):
        print("option two is okay")
class B(A):                           
    def option3(self):                   
        print("option 3 is okay")
    def option4(self):
        print("option 4 is okay")
a1=B()
# Out:
# in  a init

# %%
class A: 
    def __init__(self):
        print("in  a init")
    def option1(self):
        print("option one okay")
    def option2(self):
        print("option two is okay")
class B(A):
    def __init__(self):
        print("in  b init")
    def option3(self):                   
        print("option 3 is okay")
    def option4(self):
        print("option 4 is okay")
a1=B()
# Out:
# in  b init

# %% [markdown]
# # polymorphism

# %% [raw]
# The word "polymorphism" means "many forms", and in programming it refers to methods/functions/operators with the same name that can be executed on many objects or classes.
# Polymorphism is often used in Class methods, where we can have multiple classes with the same method name.
# 4 ways to implement
# 1) duck typing
# 2)operator overloading
# 3)method overloading
# 4)method overriding

# %%
class Car:
  def __init__(self, brand, model):
    self.brand = brand
    self.model = model

  def move(self):
    print("Drive!")

class Boat:
  def __init__(self, brand, model):
    self.brand = brand
    self.model = model

  def move(self):
    print("Sail!")

class Plane:
  def __init__(self, brand, model):
    self.brand = brand
    self.model = model

  def move(self):
    print("Fly!")

car1 = Car("Ford", "Mustang")       #Create a Car object
boat1 = Boat("Ibiza", "Touring 20") #Create a Boat object
plane1 = Plane("Boeing", "747")     #Create a Plane object

for x in (car1, boat1, plane1):
  x.move()
# Out:
# Drive!
# Sail!
# Fly!

# %%
#duck typing
#if it quakes like a duck if it behaves like a duck then it is a duck

class pycharm:
    def execute(self):
        print("compiling")
        print("running")

class laptop:
    def code(self,ide):
        ide.execute()

ide=pycharm()
obj1=laptop()
obj1.code(ide)
# Out:
# compiling
# running

# %%
class pycharm:
    def execute(self):          #has execute
        print("compiling")
        print("running")
class myeditor:                #if there is object and it has a method then thats it we call it
    def execute(self):          #has execute
        print("parsing")
        print("compiling")
        print("running")
class laptop:
    def code(self,ide):
        ide.execute()

ide=myeditor()              #we can get any
obj1=laptop()
obj1.code(ide)
# Out:
# parsing
# compiling
# running

# %%
#operator overloading

a=5
b=4
print(a+b)
print(int.__add__(a,b))
# Out:
# 9
# 9

# %%
class student:
    def __init__(self,m1,m2):
        self.m1=m1
        self.m2=m2
    def __add__(self,other):      #we can over ride the operator function
        m1=self.m1+other.m1
        m2=self.m2+other.m2
        s3=student(m1,m2)
        return s3
        
s1=student(65,25)
s2=student(95,76)
s3=s1+s2
a=10
print(a)   #backend __str__ 
print(s1.__str__())
# Out:
# 10
# ...

# %%
class student:
    def __init__(self,m1,m2):
        self.m1=m1
        self.m2=m2
    def __add__(self,other):      #we can over ride the operator function
        m1=self.m1+other.m1
        m2=self.m2+other.m2
        s3=student(m1,m2)
        return s3
    def __str__(self):
        return '{} {}'.format(self.m1, self.m2)  #now after changing the functiong prints values
s1=student(65,25)
s2=student(95,76)
s3=s1+s2
a=10
print(a)   #backend __str__ 
print(s1.__str__())
# Out:
# 10
# 65 25

# %%
#method overloading    doesnt support
#student
#def average(a,b)
#def average(a,b,c)

# we can archive it through
# default arguments -none / default arguments c=0/ *args/ 
class student:
    def __init__(self,m1,m2):
        self.m1=m1
        self.m2=m2
    def sum(self,a=None,b=None,c=None):
        s=0
        if a!=None and b!=None and c!=None:
            s=a+b+c
        elif a!=None and b!=None:
            s=a
        return
        

s1=student(65,25)
print(s1.sum(5,10))
# Out:
# None

# %%
class Demo:                #this is method over loading  and we can archive it through above example
    def add(self,a,b):
        return a+b
    def add(self,a,b,c):
        return a+b+c
d=Demo()
print(d.add(2,3))
print(d.add(3,4,5))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[163], line 7
#       5         return a+b+c
#       6 d=Demo()
# ----> 7 print(d.add(2,3))
#       8 print(d.add(3,4,5))
#
# TypeError: Demo.add() missing 1 required positional argument: 'c'

# %%
#over riding      doest support

class A:
    def show(self):
        print("in A show")
class B(A):                     # when you dont have show in b it prints show of a 
    def show(self):             # when you have show in b it prints show of b 
        print("in B show")
    

a1=A()
a1.show()
# Out:
# in A show

# %%
class Shape:
  def __init__(self, x, y):
    self.x = x
    self.y = y
    
  def area(self):
      return self.x * self.y

class Circle(Shape):
    def __init__(self, radius):
      self.radius = radius
      super().__init__(radius, radius)

    def area(self):                          #method over riding
        return 3.14 *  super().area()        #circle area over rides shape area
                                             #using super we can get both child and parent area
# rec = Shape(3, 5)
# print(rec.area())

c = Circle(5)
print(c.area())
# Out:
# 78.5

# %% [raw]
# #access modifiers       (not there in python but we asume convention)
# 1. public access modifiers
# 2. private access modifiers
# 3. protected access modifiers

# %%
#public
class employee:
    def __init__(self):
        self.name="sai"
a = employee()
print(a.name)
# Out:
# sai

# %%
#private         (using __)
class employee:
    def __init__(self):
        self.__name ="sai"
        
a = employee()
#print(a.__name)           cannot be accessed
print(a._employee__name)    # can be accessed(name mangling)
# Out:
# sai

# %%
class Student:
    def __init__(self):
        self._name = "Harry"

    def _funName(self):      # protected method    (using single _)
        return "CodeWithHarry"

class Subject(Student):       #inherited class
    pass

obj = Student()
obj1 = Subject()
print(dir(obj))

# calling by object of Student class
print(obj._name)      
print(obj._funName())     
# calling by object of Subject class
print(obj1._name)    
print(obj1._funName())
# Out:
# ['__class__', '__delattr__', '__dict__', '__dir__', '__doc__', '__eq__', '__firstlineno__', '__format__', '__ge__', '__getattribute__', '__getstate__', '__gt__', '__hash__', '__init__', '__init_subclass__', '__le__', '__lt__', '__module__', '__ne__', '__new__', '__reduce__', '__reduce_ex__', '__repr__', '__setattr__', '__sizeof__', '__static_attributes__', '__str__', '__subclasshook__', '__weakref__', '_funName', '_name']
# Harry
# CodeWithHarry
# Harry
# CodeWithHarry

# %% [markdown]
# # encapsulation

# %% [raw]
# Encapsulation is about protecting data inside a class.
# It means keeping data (properties) and methods together in a class, while controlling how the data can be accessed from outside the class.

# %%
class Person:
  def __init__(self, name, age):
    self.name = name
    self.__age = age # Private property

p1 = Person("Emil", 25)
print(p1.name)
print(p1.__age) # This will cause an error
# Out:
# Emil
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[169], line 8
#       6 p1 = Person("Emil", 25)
#       7 print(p1.name)
# ----> 8 print(p1.__age)
#
# AttributeError: 'Person' object has no attribute '__age'

# %%
class Person:
  def __init__(self, name, age):
    self.name = name
    self.__age = age

  def get_age(self):
    return self.__age

p1 = Person("Tobias", 25)
print(p1.get_age())
# Out:
# 25

# %%
class Calculator:
  def __init__(self):
    self.result = 0

  def __validate(self, num):
    if not isinstance(num, (int, float)):
      return False
    return True

  def add(self, num):
    if self.__validate(num):
      self.result += num
    else:
      print("Invalid number")

calc = Calculator()
calc.add(10)
calc.add(5)
print(calc.result)
# calc.__validate(5) # This would cause an error
# Out:
# 15

# %% [markdown]
# # abstract classes

# %% [raw]
# by default python dosent support but we can archive

# %%
from abc import ABC, abstractmethod
class Computer(ABC):      #abstract method
    @abstractmethod
    def process(self):       #abstract method
        pass

com=Computer()
com.process()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[174], line 7
#       3     @abstractmethod
#       4     def process(self):       #abstract method
#       5         pass
# ----> 7 com=Computer()
#       8 com.process()
#
# TypeError: Can't instantiate abstract class Computer without an implementation for abstract method 'process'

# %%
from abc import ABC, abstractmethod
class Computer(ABC):      #abstract method
    @abstractmethod
    def process(self):       #abstract method
        pass

class Laptop(Computer):
    def process(self):
        print("its running")

#com=Computer()
com1=Laptop()
#com.process()
com1.process()
# Out:
# its running

# %% [markdown]
# # iterators

# %%
#iterator is an object that contains countable no of values
#lists,tuples,dict,set are iterabale
#to iterate in opps

nums=[5,3,7,9,4,8]
print(nums[2])

# %%
nums=[5,3,7,9,4,8]

for i in nums:
    print(i)
# Out:
# 5
# 3
# 7
# 9
# 4
# 8

# %%
nums=[5,3,7,9,4,8]
it=iter(nums)
print(it.__next__())    #picks one value
print(it.__next__())

print(next(it))

for i in nums:  #prints all
    print(i)
# Out:
# 5
# 3
# 7
# 5
# 3
# 7
# 9
# 4
# 8

# %%
mytuple=('sai','kiran','chand')
myit=iter(mytuple)
print(next(myit))
print(myit.__next__())
for i in myit:
    print(i)
# Out:
# sai
# kiran
# chand

# %% [markdown]
# # generators

# %%
#generators gives iterators
#instead of using iter and next
#uses yield
#we can wite multiple yield

# %%
def topten():
    yield 10
    yield 20
    yield 30

values=topten()
print(values.__next__())
print(next(values))
for i in values:
    print(i)
# Out:
# 10
# 20
# 30

# %%
def topten():
    n=1
    while n <= 10:
        sq=n*n
        yield sq
        n+=1

values=topten()
for i in values:
    print(i)
# Out:
# 1
# 4
# 9
# 16
# 25
# 36
# 49
# 64
# 81
# 100

# %%
def my_generator():
    for i in range(5):
        yield i
gen = my_generator()
print(gen.__next__())   #on the go
print(next(gen))
for j in gen:
    print(j)
# Out:
# 0
# 1
# 2
# 3
# 4

# %% [markdown]
# # multi threading

# %%
class hello:
    def run(self):
        for i in range(5):
            print("hello")
class hi:
    def run(self):
        for i in range(5):
            print("hi")
t1=hello()
t2=hi()

print(t1.run())
print(t2.run())
# Out:
# hello
# hello
# hello
# hello
# hello
# None
# hi
# hi
# hi
# hi
# hi
# None

# %%
from threading import *

class hello(Thread):
    def run(self):
        for i in range(5):
            print("hello")
class hi(Thread):
    def run(self):
        for i in range(5):
            print("hi")
t1=hello()
t2=hi()

print(t1.start())     #start internally calls run
print(t2.start())
# Out:
# helloNone
#
# hello
# hello
# hello
# hello
# hi
# hi
# hi
# hi
# hi
# None

# %%
from time import sleep
from threading import *

class hello(Thread):
    def run(self):
        for i in range(5):
            print("hello")
            sleep(1)
class hi(Thread):
    def run(self):
        for i in range(5):
            print("hi")
            sleep(1)
t1=hello()
t2=hi()

print(t1.start())     #start internally calls run
sleep(2)
print(t2.start())

t1.join()
t2.join()
print('bye')
# Out:
# hello
# None
# hello
# hello
# hi
# None
# hellohi
#
# hihello
#
# hi
# hi
# bye

# %% [markdown]
# # file handling

# %%
#The key function for working with files in Python is the open() function.
# "r" - Read - Default value. Opens a file for reading, error if the file does not exist
# "a" - Append - Opens a file for appending, creates the file if it does not exist
# "w" - Write - Opens a file for writing, creates the file if it does not exist
# "x" - Create - Creates the specified file, returns an error if the file exists

# %%
f = open('filename','r')
print(f.read())       #reads complete file
print(f.readline())    #prints one line

f = open('filename','w')
print(f.read())       #writes complete file
f.write('something')    #writes to the file

f = open('filename','a')
print(f.read())       #appends data to the file
f.write('something')

# %%
f = open('image file name','rb')

f=open('mypic','wb')
for i in f:
    f1.write(i)
