# %% [markdown]
# # pandas

# %% [markdown]
# * Pandas is a Python library.
# * Pandas is used to analyze data.
# * It has functions for analyzing, cleaning, exploring, and manipulating data.
# *

# %%
import pandas

mydataset = {
  'cars': ["BMW", "Volvo", "Ford"],
  'passings': [3, 7, 2]
}

myvar = pandas.DataFrame(mydataset)

print(myvar)
# Out:
#     cars  passings
# 0    BMW         3
# 1  Volvo         7
# 2   Ford         2

# %%
import pandas as pd

# %%
pd.__version__
# Out:
# '2.2.3'

# %%
a = [1, 7, 2]              #A Pandas Series is like a column in a table.It is a one-dimensional array holding data of any type.
myvar = pd.Series(a)
print(myvar)
# Out:
# 0    1
# 1    7
# 2    2
# dtype: int64

# %%
print(myvar[0])
# Out:
# 1

# %%
a = [1, 7, 2]                 # Create Labels With the index argument, you can name your own labels.
myvar = pd.Series(a, index = ["x", "y", "z"])
print(myvar)
# Out:
# x    1
# y    7
# z    2
# dtype: int64

# %%
calories = {"day1": 420, "day2": 380, "day3": 390}     #Key/Value Objects as Series You can also use a key/value object, like a dictionary, when creating a Series.
myvar = pd.Series(calories)
print(myvar)
# Out:
# day1    420
# day2    380
# day3    390
# dtype: int64

# %%
data = {                             #creating a data frame
  "calories": [420, 380, 390],
  "duration": [50, 40, 45]
}
myvar = pd.DataFrame(data)
print(myvar)
# Out:
#    calories  duration
# 0       420        50
# 1       380        40
# 2       390        45

# %%
data = {                           #naming the indexes
  "calories": [420, 380, 390],
  "duration": [50, 40, 45]
}
df = pd.DataFrame(data, index=['day1','day2','day3'])
print(df)
# Out:
#       calories  duration
# day1       420        50
# day2       380        40
# day3       390        45

# %%
df=pd.read_csv("sales_data_sample.csv",encoding="latin1")     
df
# Out:
#       ORDERNUMBER  QUANTITYORDERED  PRICEEACH  ORDERLINENUMBER    SALES  \
# 0           10107               30      95.70                2  2871.00
# 1           10121               34      81.35                5  2765.90
# 2           10134               41      94.74                2  3884.34
# 3           10145               45      83.26                6  3746.70
# 4           10159               49     100.00               14  5205.27
# ...           ...              ...        ...              ...      ...
# 2818        10350               20     100.00               15  2244.40
# 2819        10373               29     100.00                1  3978.51
# 2820        10386               43     100.00                4  5417.57
# 2821        10397               34      62.24                1  2116.16
# 2822        10414               47      65.52                9  3079.44
#
#             ORDERDATE    STATUS  QTR_ID  MONTH_ID  YEAR_ID  ...  \
# ...

# %%
df=pd.read_csv(r'C:\Users\Sai\A in Acodes\data science\4. pandas\sales_data_sample.csv',encoding='latin1')
df
# Out:
#       ORDERNUMBER  QUANTITYORDERED  PRICEEACH  ORDERLINENUMBER    SALES  \
# 0           10107               30      95.70                2  2871.00
# 1           10121               34      81.35                5  2765.90
# 2           10134               41      94.74                2  3884.34
# 3           10145               45      83.26                6  3746.70
# 4           10159               49     100.00               14  5205.27
# ...           ...              ...        ...              ...      ...
# 2818        10350               20     100.00               15  2244.40
# 2819        10373               29     100.00                1  3978.51
# 2820        10386               43     100.00                4  5417.57
# 2821        10397               34      62.24                1  2116.16
# 2822        10414               47      65.52                9  3079.44
#
#             ORDERDATE    STATUS  QTR_ID  MONTH_ID  YEAR_ID  ...  \
# ...

# %%
#store=pd.read_csv(r'C:\Users\Sai\naresh it codes\pandas\Sample - Superstore_Orders.csv')
#store

# %%
#df=pd.read_excel("SampleSuperstore.xlsx")
#df

# %%
df=pd.read_json("sample_Data.json")
df
# Out:
#     id                                               name  \
# 0    1                                    Apple iPhone 12
# 1    2                                 Samsung Galaxy S21
# 2    3                                 Sony PlayStation 5
# 3    4                  LG OLED55CXPUA 55-inch 4K OLED TV
# 4    5        Bose QuietComfort 35 II Wireless Headphones
# 5    6                          Fitbit Versa 3 Smartwatch
# 6    7                             KitchenAid Stand Mixer
# 7    8                 Dyson V11 Absolute Cordless Vacuum
# 8    9                         Ninja Foodi Smart XL Grill
# 9   10                    Canon EOS Rebel T8i DSLR Camera
# 10  11                                  Apple AirPods Pro
# 11  12        Bose QuietComfort 35 II Wireless Headphones
# 12  13                    Fitbit Charge 4 Fitness Tracker
# 13  14                              Samsung Galaxy Watch3
# 14  15  Sony WH-1000XM4 Wireless Noise-Cancelling Head...
# ...

# %%
data={
    "name":['ram','shyam','sai'],
    "age":[10,20,30],
    "city":['x','y','z']
}
df=pd.DataFrame(data)
df
# Out:
#     name  age city
# 0    ram   10    x
# 1  shyam   20    y
# 2    sai   30    z

# %%
df.to_csv("output.csv",index=False)        #saving as csv xlsx and json
df

df.to_excel("output.xlsx",index=False)
df

df.to_json("output.json",index=False)
df

# %%
df.tail()

# %%
df=pd.read_json("sample_Data.json")
df

df.head(10)
df.tail()

# %%
df.info()

# %%
df.describe()       #calculates the total column summary   idd for ints,floats and objests

# %%
df.shape

# %%
df.columns

# %%
df

# %%
df['calories']     #accesing columns

# %%
df.loc[0]

# %%
df[['calories','duration']]        #accesing multiple columns

# %%
df.loc[[0,1]]

# %%
#to filter rows

df[(df["duration"]<50)]

# %%
df[(df["duration"]<50) & (df['calories']>380)]       #filter multi[le rows

# %%
df[(df["duration"]<50) | (df['calories']<400)]

# %%
# #changing column name and row names
# #cloumns
# store.columns=['','','','',........all new column names']

# #rows
# data = {
#   "calories": [420, 380, 390],
#   "duration": [50, 40, 45]
# }
# df = pd.DataFrame(data, index = ["day1", "day2", "day3"])
# print(df)

# %%
#adding elements

df

# %%
data={
    "Name":['Ram','Shyam','Ghanesh','Ddhanush','Aditi','Jagdish','Raj','Simran'],
    "Age":[28,34,22,30,29,40,25,32],
    "Salary":[50000,60000,45000,52000,49000,70000,48000,58000],
    "Performance_Score":[85,90,78,92,88,95,80,89]
}
df=pd.DataFrame(data)
print(df)

# %%
df["Bonus"]=df['Salary']*0.1          #add column
df

# %%
df.insert(0,"Employee_N",[10,20,30,40,50,60,70,80])       #add using insert
df                                                      #df.insert(loc,"columnname",data

# %%
#updating value
df.loc[0,'Salary']=45000            #updating 1 value
df

# %%
df["Annual"]=df['Salary']*12          #add column
df

# %%
df.drop('salary',axis=1)                   #drop element

# %% [markdown]
# updating

# %%
df.loc[0,'Salary']=55000
df

# %%
df['Age']=df['Age']+1
df

# %%
df.drop('salary',axis=1)                   #drop element

# %%
# df.drop(columns=['Bonus','Annual'],axis=1,inplace=True)
# df

# %% [markdown]
# handling missing data

# %%
data={
    "Name":['Ram','Shyam','Ghanesh','Ddhanush','Aditi','Jagdish','Raj','Simran'],
    "Age":[28,34,22,30,None,240,25,32],
    "Salary":[50000,60000,45000,52000,49000,70000,48000,58000],
    "Performance_Score":[85,90,78,92,88,None,None,89]
}
df=pd.DataFrame(data)
print(df)

# %%
df.isnull()

# %%
df.isnull().sum()

# %%
df.dropna(inplace=True)
df

# %%
df.fillna(0,inplace=True)          #insted of none giving a value 0
df

# %%
df['Age'].fillna(df['Age'].mean(),inplace=True)
df

# %% [markdown]
# #interpolation      predicts the missing number    #linear,polynomial,time etcc

# %%
df.interpolate(method="linear", axis=0,inplace=True)
df

# %%
data={
    "time":[1,2,3,4,5],
    "value":[10,None,30,None,50]
}
df=pd.DataFrame(data)
print(df)
df["value"]=df['value'].interpolate(method="linear")
print("after interpolation")
df

# %% [markdown]
# #Sorting and aggregration

# %%
#sorting data in 1 column sort_values()
data={
    "Name":['Ram','Shyam','Ghanesh','Ddhanush'],
    "Age":[28,34,22,30],
    "Salary":[50000,60000,45000,62000],
    "Performance_Score":[85,90,78,92]
}
df=pd.DataFrame(data)
df.sort_values(by="Age",ascending=True, inplace=True)
df
# Out:
#        Name  Age  Salary  Performance_Score
# 2   Ghanesh   22   45000                 78
# 0       Ram   28   50000                 85
# 3  Ddhanush   30   62000                 92
# 1     Shyam   34   60000                 90

# %%
data={
    "Name":['Ram','Shyam','Ghanesh','Ddhanush'],
    "Age":[28,34,22,30],
    "Salary":[50000,60000,45000,62000],
    "Performance_Score":[85,90,78,92]
}
df=pd.DataFrame(data)
df.sort_values(by=["Age","Salary"],ascending=[True,False], inplace=True)
df
# Out:
#        Name  Age  Salary  Performance_Score
# 2   Ghanesh   22   45000                 78
# 0       Ram   28   50000                 85
# 3  Ddhanush   30   62000                 92
# 1     Shyam   34   60000                 90

# %% [markdown]
# aggegration

# %%
data={
    "Name":['Ram','Shyam','Ghanesh','Ddhanush'],
    "Age":[28,34,22,30],
    "Salary":[50000,60000,45000,62000],
    "Performance_Score":[85,90,78,92]
}
df=pd.DataFrame(data)
meandata=df["Salary"].mean()           #similarly sum(), min() , max() , count() , std()
meandata
# Out:
# np.float64(54250.0)

# %% [markdown]
# grouping

# %%
data={
    "Name":['Ram','Shyam','Ghanesh','Ddhanush','Aditi','Jagdish','Raj','Simran'],
    "Age":[28,34,22,30,28,34,25,32],
    "Salary":[50000,60000,45000,52000,49000,70000,48000,58000],
    "Performance_Score":[85,90,78,92,88,None,None,89]
}
df=pd.DataFrame(data)
grouped=df.groupby("Age")["Salary"].mean()              #groups the similar age then caluculates the mean
grouped
# Out:
# Age
# 22    45000.0
# 25    48000.0
# 28    49500.0
# 30    52000.0
# 32    58000.0
# 34    65000.0
# Name: Salary, dtype: float64

# %% [markdown]
# Merging and Joining

# %%
df_customers= pd.DataFrame({
    'Customerid':
# Out:
#   Cell In[27], line 2
#     'Customerid':
#                  ^
# _IncompleteInputError: incomplete input
