# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
import warnings
warnings.filterwarnings('ignore')

# %%
data = {"days":[1,2,3,4,5],
        "nop":[50,25,75,35,78]}
df=pd.DataFrame(data)
df
# Out:
#    days  nop
# 0     1   50
# 1     2   25
# 2     3   75
# 3     4   35
# 4     5   78

# %%
#seaborn
sns.lineplot(data=data,x="days",y="nop")
plt.show()

# %%
#matplotlib
days=[1,2,3,4,5]
nop=[10,40,20,50,70]

plt.plot(days,nop)
plt.show()

# %%
movies=pd.read_csv(r"C:\Users\Sai\A in Acodes\data science\5. seaborn\Movie-Rating.csv")

# %%
movies
# Out:
#                       Film      Genre  Rotten Tomatoes Ratings %  \
# 0    (500) Days of Summer      Comedy                         87
# 1              10,000 B.C.  Adventure                          9
# 2               12 Rounds      Action                         30
# 3                127 Hours  Adventure                         93
# 4                17 Again      Comedy                         55
# ..                     ...        ...                        ...
# 554          Your Highness     Comedy                         26
# 555        Youth in Revolt     Comedy                         68
# 556                 Zodiac   Thriller                         89
# 557            Zombieland      Action                         90
# 558              Zookeeper     Comedy                         14
#
#      Audience Ratings %  Budget (million $)  Year of release
# 0                    81                   8             2009
# 1                    44                 105             2008
# ...

# %%
len(movies)
# Out:
# 559

# %%
type(movies)
# Out:
# pandas.core.frame.DataFrame

# %%
import numpy
print(numpy.__version__)
# Out:
# 2.1.3

# %%
import pandas
print(pandas.__version__)
# Out:
# 2.2.3

# %%
movies.columns
# Out:
# Index(['Film', 'Genre', 'Rotten Tomatoes Ratings %', 'Audience Ratings %',
#        'Budget (million $)', 'Year of release'],
#       dtype='object')

# %%
movies.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 559 entries, 0 to 558
# Data columns (total 6 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Film                       559 non-null    object
#  1   Genre                      559 non-null    object
#  2   Rotten Tomatoes Ratings %  559 non-null    int64
#  3   Audience Ratings %         559 non-null    int64
#  4   Budget (million $)         559 non-null    int64
#  5   Year of release            559 non-null    int64
# dtypes: int64(4), object(2)
# memory usage: 26.3+ KB

# %%
movies.shape
# Out:
# (559, 6)

# %%
movies.head()
# Out:
#                     Film      Genre  Rotten Tomatoes Ratings %  \
# 0  (500) Days of Summer      Comedy                         87
# 1            10,000 B.C.  Adventure                          9
# 2             12 Rounds      Action                         30
# 3              127 Hours  Adventure                         93
# 4              17 Again      Comedy                         55
#
#    Audience Ratings %  Budget (million $)  Year of release
# 0                  81                   8             2009
# 1                  44                 105             2008
# 2                  52                  20             2009
# 3                  84                  18             2010
# 4                  70                  20             2009

# %%
movies.tail()
# Out:
#                 Film     Genre  Rotten Tomatoes Ratings %  Audience Ratings %  \
# 554    Your Highness    Comedy                         26                  36
# 555  Youth in Revolt    Comedy                         68                  52
# 556           Zodiac  Thriller                         89                  73
# 557      Zombieland     Action                         90                  87
# 558        Zookeeper    Comedy                         14                  42
#
#      Budget (million $)  Year of release
# 554                  50             2011
# 555                  18             2009
# 556                  65             2007
# 557                  24             2009
# 558                  80             2011

# %%
movies.columns
# Out:
# Index(['Film', 'Genre', 'CriticalRating', 'AudienceRating', 'BudgetMillions',
#        'Year'],
#       dtype='object')

# %%
movies.columns=['Film','Genre','CriticalRating','AudienceRating','BudgetMillions','Year']   #change column names

# %%
movies.head()
# Out:
#                     Film      Genre  CriticalRating  AudienceRating  \
# 0  (500) Days of Summer      Comedy              87              81
# 1            10,000 B.C.  Adventure               9              44
# 2             12 Rounds      Action              30              52
# 3              127 Hours  Adventure              93              84
# 4              17 Again      Comedy              55              70
#
#    BudgetMillions  Year
# 0               8  2009
# 1             105  2008
# 2              20  2009
# 3              18  2010
# 4              20  2009

# %%
movies.head(1)
# Out:
#                     Film   Genre  CriticalRating  AudienceRating  \
# 0  (500) Days of Summer   Comedy              87              81
#
#    BudgetMillions  Year
# 0               8  2009

# %%
movies.shape
# Out:
# (559, 6)

# %%
movies.describe()
# Out:
#        CriticalRating  AudienceRating  BudgetMillions
# count      559.000000      559.000000      559.000000
# mean        47.309481       58.744186       50.236136
# std         26.413091       16.826887       48.731817
# min          0.000000        0.000000        0.000000
# 25%         25.000000       47.000000       20.000000
# 50%         46.000000       58.000000       35.000000
# 75%         70.000000       72.000000       65.000000
# max         97.000000       96.000000      300.000000

# %%
movies.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 559 entries, 0 to 558
# Data columns (total 6 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Film            559 non-null    category
#  1   Genre           559 non-null    category
#  2   CriticalRating  559 non-null    int64
#  3   AudienceRating  559 non-null    int64
#  4   BudgetMillions  559 non-null    int64
#  5   Year            559 non-null    category
# dtypes: category(3), int64(3)
# memory usage: 36.5 KB

# %%
movies.Film=movies.Film.astype('category')         #changing the type
movies.Genre=movies.Genre.astype('category')
movies.Year=movies.Year.astype('category')

# %%
movies.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 559 entries, 0 to 558
# Data columns (total 6 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Film            559 non-null    category
#  1   Genre           559 non-null    category
#  2   CriticalRating  559 non-null    int64
#  3   AudienceRating  559 non-null    int64
#  4   BudgetMillions  559 non-null    int64
#  5   Year            559 non-null    category
# dtypes: category(3), int64(3)
# memory usage: 36.5 KB

# %%
movies.describe()
# Out:
#        CriticalRating  AudienceRating  BudgetMillions
# count      559.000000      559.000000      559.000000
# mean        47.309481       58.744186       50.236136
# std         26.413091       16.826887       48.731817
# min          0.000000        0.000000        0.000000
# 25%         25.000000       47.000000       20.000000
# 50%         46.000000       58.000000       35.000000
# 75%         70.000000       72.000000       65.000000
# max         97.000000       96.000000      300.000000

# %% [markdown]
# # styling and color

# %%
sns.barplot(data=movies,x='CriticalRating',y='Year')
sns.set_style(style="dark")
plt.show()

# %%
sns.barplot(data=movies,x='CriticalRating',y='Year')
sns.set_style(style="whitegrid")
plt.show()

# %%
# How to working with joint plots

from matplotlib import pyplot as plt
import seaborn as sns
# %matplotlib inline
import warnings
warnings.filterwarnings('ignore')

# %%
l1=sns.lineplot(data=movies,x="CriticalRating",y="Year")
plt.show()

# %%
l1=sns.lineplot(data=movies,x="CriticalRating",y="AudienceRating",hue="Year")
plt.show()

# %%
#barplot                   #shirift plus tab to see all the functions
sns.barplot(data=movies,x='CriticalRating',y='Year',)
plt.show()

# %%
j=sns.jointplot(data=movies,x='CriticalRating',y='AudienceRating')
plt.show()

# %%
j=sns.jointplot(data=movies,x='CriticalRating',y='AudienceRating',kind='hex')
plt.show()

# %%
j=sns.jointplot(data=movies,x='CriticalRating',y='AudienceRating',kind='kde')
plt.show()

# %%
m1 = sns.displot(movies.AudienceRating)
plt.show()

# %%
m1 = sns.distplot(movies.AudienceRating)
plt.show()

# %%
sns.set_style('darkgrid') 
m1 = sns.distplot(movies.AudienceRating)
plt.show()

# %%
m2 = sns.distplot(movies.AudienceRating, bins = 15)
plt.show()

# %%
#sns.set_style('darkgrid')
n1 = plt.hist(movies.AudienceRating, bins=15)
plt.show()

# %%
n1 = sns.histplot(data=movies,x='CriticalRating',y='Year')
plt.show()

# %%
sns.set_style('white') #normal distribution & called as bell curve
n1 = plt.hist(movies.AudienceRating, bins=20)
plt.show()

# %%
n1 = plt.hist(movies.CriticalRating, bins=20) #uniform distribution
plt.show()

# %%
#h1 = plt.hist(movies.BudgetMillions)

plt.hist(movies.BudgetMillions)
plt.show()

# %%
plt.hist(movies[movies.Genre == 'Drama'].BudgetMillions)
plt.show()

# %%
movies.head()
# Out:
#                     Film      Genre  CriticalRating  AudienceRating  \
# 0  (500) Days of Summer      Comedy              87              81
# 1            10,000 B.C.  Adventure               9              44
# 2             12 Rounds      Action              30              52
# 3              127 Hours  Adventure              93              84
# 4              17 Again      Comedy              55              70
#
#    BudgetMillions  Year
# 0               8  2009
# 1             105  2008
# 2              20  2009
# 3              18  2010
# 4              20  2009

# %%
n1 = sns.scatterplot(data=movies,x='CriticalRating',y='AudienceRating')
plt.show()

# %%
n1 = sns.scatterplot(data=movies,x='CriticalRating',y='AudienceRating',hue="Year")
plt.show()

# %%
n1 = sns.scatterplot(data=movies,x='CriticalRating',y='AudienceRating',hue="Year",size="Year")
plt.show()

# %%
#heatmap

gp=movies.groupby("Year").agg({"CriticalRating":"mean"})
sns.heatmap(gp)
plt.show()

# %%
#count plot

n1 = sns.countplot(data=movies,x='Year')
plt.show()

# %%
n1 = sns.countplot(data=movies,x='CriticalRating')
plt.show()

# %%
n1 = sns.violinplot(data=movies,x='CriticalRating',y='Year')
plt.show()

# %%
#pairplot

n1 = sns.pairplot(movies)
plt.show()

# %%
n1 = sns.pairplot(movies,hue="Year")
plt.show()

# %%
n1 = sns.stripplot(data=movies,x='CriticalRating',y='Year')
plt.show()

# %%
n1 = sns.scatterplot(data=movies,x='CriticalRating',y='Year')
plt.show()

# %%
n1 = sns.boxplot(data=movies,x='CriticalRating')
plt.show()

# %%
n1 = sns.boxplot(data=movies,x='CriticalRating',y='Year')
plt.show()

# %%
n1 = sns.catplot(data=movies,x='CriticalRating',y='Year')
plt.show()

# %%
n1 = sns.catplot(data=movies,x='CriticalRating',y='Year',kind="bar")
plt.show()

# %%
#multiple plot
